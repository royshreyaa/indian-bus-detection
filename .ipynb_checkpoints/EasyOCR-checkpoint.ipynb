# %%
import os
import re
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img = cv2.imread(r'Dataset/Original/FrontBus/IMG_3640.jpg')
plt.imshow(img)

# %%
reader = easyocr.Reader(['en'], gpu=False)
result = reader.readtext(img,paragraph="False")
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [[[[71, 455], [157, 455], [157, 493], [71, 493]], 'PMP'],
#  [[[325, 495], [387, 495], [387, 511], [325, 511]], 'VRFR'],
#  [[[299, 511], [445, 511], [445, 555], [299, 555]], 'aimuriT'],
#  [[[100, 586], [185, 586], [185, 647], [100, 647]], '70 " d135'],
#  [[[292, 584], [378, 584], [378, 614], [292, 614]], 'TATA'],
#  [[[491, 587], [602, 587], [602, 653], [491, 653]], 'Marcopolo C696'],
#  [[[0, 618], [57, 618], [57, 687], [0, 687]], '"12 6204'],
#  [[[646, 611], [759, 611], [759, 688], [646, 688]], 'vC % B1 easoW'],
#  [[[298, 832], [390, 832], [390, 892], [298, 892]], 'NH12 RN6204']]

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    print(text)
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),2)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(255,0,0),1,cv2.LINE_AA)
    spacer+=15
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
# Out:
# PMP
# VRFR
# aimuriT
# 70 " d135
# TATA
# Marcopolo C696
# "12 6204
# vC % B1 easoW
# NH12 RN6204

# %%
result_array = np.array(result)

# Extract the last column of the array
last_column = result_array[:, -1]

# Print the last column
print(last_column)
# Out:
# ['PMP' 'VRFR' 'aimuriT' '70 " d135' 'TATA' 'Marcopolo C696' '"12 6204'
#  'vC % B1 easoW' 'NH12 RN6204']
# C:\Users\Shreya Roy\AppData\Local\Temp\ipykernel_47920\1223956250.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result_array = np.array(result)

# %%
desired_string = ''
for text in last_column:
    if 'marcopolo' in text.lower():
        # Extract the string before and after 'marcopolo'
        parts = text.lower().split('marcopolo')
        if len(parts) == 2:
            # Combine the two parts of the string without 'marcopolo'
            desired_string = parts[0] + parts[1]

# Print the desired string
print(desired_string)
# Out:
#  c696

# %%
for string in last_column:
    # Use regex to search for pattern of 3 numbers in the string
    match = re.search(r'\d{3}', string)
    if match:
        # If match is found, display the numbers
        numbers = match.group()
        print(numbers)
# Out:
# 135
# 696
# 620
# 620
